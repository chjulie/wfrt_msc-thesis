# %%
import pandas as pd 
import geopandas as gpd

# %%
shp_path = '../data/geometric_data/MDA_ADP_08_DrainageBasin_BassinDeDrainage.shx'

# %%
data = gpd.read_file(shp_path)

# %%
data.head(5)
# Out:
#                                             geometry
# 0  POLYGON ((-2069880 2988600, -2069850 2988600, ...
# 1  POLYGON ((-2082960 2882160, -2083050 2882160, ...
# 2  POLYGON ((-2105880 2929650, -2105910 2929650, ...
# 3  POLYGON ((-2045280 2993880, -2045340 2993880, ...
# 4  POLYGON ((-2041530 3038970, -2041530 3039000, ...

# %%
data.describe()
# Out:
#                                                  geometry
# count                                                2180
# unique                                               2141
# top     POLYGON ((-1559460 1274370, -1559490 1274370, ...
# freq                                                    7

# %%
data.boundary.plot()
# Out:
# <Axes: >

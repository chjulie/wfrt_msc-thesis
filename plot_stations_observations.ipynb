# %%
import polars as pl
import os
import matplotlib.pyplot as plt
import cartopy.feature as cfeatures
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import os
#       3 import matplotlib.pyplot as plt
# ----> 4 import cartopy.feature as cfeatures
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
DATA_FOLDER = "observation_data"
FILE_NAME = "stations_obs_2023-06-01T06:00:00.csv"

# %%
states = cfeatures.STATES.with_scale('50m')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 states = cfeatures.STATES.with_scale('50m')
#
# NameError: name 'cfeatures' is not defined

# %%
df = pl.read_csv(f"{DATA_FOLDER}/{FILE_NAME}")
print(df)
# Out:
# shape: (90, 7)
# ┌────────────┬──────────────┬───────────────┬────────────────────┬─────────────┬────────┬────────┐
# │ Station_ID ┆ Latitude_DMS ┆ Longitude_DMS ┆ accumulated_precip ┆ temperature ┆ u_wind ┆ v_wind │
# │ ---        ┆ ---          ┆ ---           ┆ ---                ┆ ---         ┆ ---    ┆ ---    │
# │ i64        ┆ i64          ┆ i64           ┆ f64                ┆ f64         ┆ str    ┆ str    │
# ╞════════════╪══════════════╪═══════════════╪════════════════════╪═════════════╪════════╪════════╡
# │ 27         ┆ 500100       ┆ -1251450      ┆ null               ┆ null        ┆ null   ┆ null   │
# │ 36         ┆ 541351       ┆ -1254552      ┆ null               ┆ null        ┆ null   ┆ null   │
# │ 113        ┆ 485006       ┆ -1255954      ┆ null               ┆ null        ┆ null   ┆ null   │
# │ 114        ┆ 495424       ┆ -1245906      ┆ null               ┆ null        ┆ null   ┆ null   │
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(df["Longitude_DMS"], df["Latitude_DMS"], marker="^")
ax3.add_feature(states, linewidth=0.5, edgecolor="black"); ax3.coastlines('50m', linewidth=0.5)
plt.show()
